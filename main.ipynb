# %%
import requests
import pandas as pd

url='http://www.cninfo.com.cn/new/data/szse_stock.json'
headers={
# 'Cookie': 'JSESSIONID=D7A0DCE786D206034F280655BA2460C4; _sp_ses.2141=*; insert_cookie=37836164; routeId=.uc2; _sp_id.2141=c0029389-4e1d-49b0-8fcc-ca65359fb7a0.1622767493.17.1652852982.1649928549.4dd68440-4343-4434-92eb-5811d472da6b',
'Host': 'www.cninfo.com.cn',
'Referer': 'http://www.cninfo.com.cn/new/commonUrl/pageOfSearch?url=disclosure/list/search&lastPage=index',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36'
}
response=requests.get(url=url,headers=headers)
json_data=response.json()
data_list=json_data["stockList"]
df=pd.DataFrame(data_list,dtype='str')
df.to_csv('firm_message.csv',index=False)
print(df)
# Out:
# d:\miniconda3\envs\mytorch\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# d:\miniconda3\envs\mytorch\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# d:\miniconda3\envs\mytorch\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
#         code pinyin category        orgId  zwjc
# 0     000001   payh       A股  gssz0000001  平安银行
# 1     000002    wka       A股  gssz0000002   万科A
# 2     000004   ghwa       A股  gssz0000004  国华网安
# 3     000005   stxy       A股  gssz0000005  ST星源
# 4     000006   szya       A股  gssz0000006  深振业A
# ...      ...    ...      ...          ...   ...
# 5647  688086   tszj       A股  gfbj0835870  退市紫晶
# 5648  688555   tszd       A股  gfbj0839097  退市泽达
# 5649  832317   gdfw       A股  gfbj0832317  观典防务
# 5650  833874   txgf       A股  gfbj0833874  泰祥股份
# 5651  833994   hbgx       A股  gfbj0833994  翰博高新
#
# [5652 rows x 5 columns]

# %%
df
# Out:
#         code pinyin category        orgId  zwjc
# 0     000001   payh       A股  gssz0000001  平安银行
# 1     000002    wka       A股  gssz0000002   万科A
# 2     000004   ghwa       A股  gssz0000004  国华网安
# 3     000005   stxy       A股  gssz0000005  ST星源
# 4     000006   szya       A股  gssz0000006  深振业A
# ...      ...    ...      ...          ...   ...
# 5647  688086   tszj       A股  gfbj0835870  退市紫晶
# 5648  688555   tszd       A股  gfbj0839097  退市泽达
# 5649  832317   gdfw       A股  gfbj0832317  观典防务
# 5650  833874   txgf       A股  gfbj0833874  泰祥股份
# 5651  833994   hbgx       A股  gfbj0833994  翰博高新
#
# [5652 rows x 5 columns]
